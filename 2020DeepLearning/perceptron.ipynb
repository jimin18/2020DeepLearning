# %%
import numpy as np

# %%
def AND(x1, x2):
  x = np.array([x1, x2])
  w = np.array([0.5,0.5])
  b= -0.7
  tmp = np.sum(w*x) + b
  if tmp <= 0:
    return 0
  else:
    return 1

# %%
AND(1,1), AND(0,0), AND(0,1)
# Out:
# (1, 0, 0)

# %%
def NAND(x1, x2):
  x = np.array([x1, x2])
  w = np.array([-0.5,-0.5])
  b= 0.7
  tmp = np.sum(w*x) + b
  if tmp <= 0:
    return 0
  else:
    return 1

# %%
NAND(1,1), NAND(0,0), NAND(0,1)
# Out:
# (0, 1, 1)

# %%
def OR(x1, x2):
  x = np.array([x1, x2])
  w = np.array([0.5,0.5])
  b= -0.2
  tmp = np.sum(w*x) + b
  if tmp <= 0:
    return 0
  else:
    return 1

# %%
OR(1,1), OR(0,0), OR(0,1)
# Out:
# (1, 0, 1)

# %%
def XOR(x1, x2):
  s1 = NAND(x1,x2)
  s2 = OR(x1, x2)
  y = AND(s1, s2)
  return y

# %%
XOR(1,1), XOR(0,0), XOR(0,1)
# Out:
# (0, 0, 1)

# %%
from google.colab import files
uploaded = files.upload() # 파일 업로드 기능 실행

for fn in uploaded.keys(): # 업로드된 파일 정보 출력
    print('User uploaded file "{name}" with length {length} bytes'.format(
        name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-7fd0c7c2-e052-414c-8298-90c0e040232f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7fd0c7c2-e052-414c-8298-90c0e040232f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 스크린샷 2020-10-13 오전 8.06.13.png to 스크린샷 2020-10-13 오전 8.06.13.png
# User uploaded file "스크린샷 2020-10-13 오전 8.06.13.png" with length 164196 bytes

# %%
from IPython.display import Image
Image('스크린샷 2020-10-13 오전 8.06.13.png')

# %%
def myOR(x1, x2):
  s1 = NAND(x1,x2)
  s2 = NAND(x1,x2)
  y = NAND(s1, s2)
  return y

# %%
myOR(1,1), myOR(0,1), myOR(1,0)
# Out:
# (1, 0, 0)
